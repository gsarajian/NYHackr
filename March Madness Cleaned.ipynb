# %% [markdown]
# # NCAA Basketball Rankings
# This is the Jupyter notebook for the data preprocessing and two ranking approaches. The data came from this site: https://masseyratings.com/scores.php?s=cb2025&sub=ncaa-d1&all=1&sch=1
#
# ## Data Preprocessing
# First, we load the necessary libraries and load and clean the data

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from numpy.linalg import eig, matrix_power

# %%
df1 = pd.read_csv("NCAA_2025.csv")
df1 = df1[['Date', 'Winner', "WinnerScore", 'Loser', 'LoserScore']]
df1 = df1.iloc[:6192] # Only keep regular season games
n = len(df1)

# %%
# Clean up data, get rid of @ symbols
arr, arr2 = [0 for i in range(n)], [0 for i in range(n)]
for i in range(n):
  arr[i] = df1["Winner"].iloc[i].replace("@", "")
  arr2[i] = df1["Loser"].iloc[i].replace("@", "")
# df1["Winner"].replace("@", "")

df1["Winner"] = arr
df1["Loser"] = arr2
df1.head()
# Out:
#          Date      Winner  WinnerScore             Loser  LoserScore
# 0  10/29/2024  S Illinois        106.0        North Park        71.0
# 1   11/4/2024       Siena         72.0             Brown        71.0
# 2   11/4/2024    Weber St        118.0  Northwest Indian        35.0
# 3   11/4/2024   Charlotte         88.0      Presbyterian        79.0
# 4   11/4/2024    Longwood         79.0      Randolph Col        68.0

# %%
teams = df1["Winner"]
teams = list(set(teams))  # only keep teams that won a game that involved a D1 team.
teams.sort()
m = len(teams)

# %% [markdown]
# ## Massey's Method
# In this next section, we'll use the Massey method as depicted in [this post](https://yetanothermathblog.com/2016/12/03/sports-ranking-methods-1/).

# %%
M = np.zeros((n, m))
b = np.zeros((n))
for i in range(n):
  game = df1.iloc[i]
  winner, loser = game["Winner"], game["Loser"]
  if winner in teams and loser in teams:
    wInd, lInd = teams.index(game["Winner"]), teams.index(game["Loser"])
    M[i][wInd] += 1
    M[i][lInd] -= 1
    b[i] += game["WinnerScore"] - game["LoserScore"]

# %%
reg = LinearRegression()
reg.fit(M, b)
# Out:
# LinearRegression()

# %%
rs = reg.coef_
expRs = [[rs[i],i] for i in range(m)]
expRs.sort()
expRs[:10]
# Out:
# [[np.float64(-25.009489638249406), 159],
#  [np.float64(-17.648249953580986), 328],
#  [np.float64(-15.112105019182376), 12],
#  [np.float64(-13.156633062994679), 63],
#  [np.float64(-13.108140644136693), 51],
#  [np.float64(-12.894923839662882), 4],
#  [np.float64(-12.106358631633185), 177],
#  [np.float64(-11.728519229194907), 204],
#  [np.float64(-11.728114416435835), 158],
#  [np.float64(-11.636745767371472), 252]]

# %%
pd.DataFrame({"Rating" : [expRs[-i-1][0] for i in range(30)], "Team" : [teams[expRs[-i-1][1]] for i in range(30)]}, index = range(1,31)).round(2)
# Out:
#     Rating            Team
# 1    21.19            Duke
# 2    19.10          Auburn
# 3    19.00         Houston
# 4    18.38         Florida
# 5    17.80         Gonzaga
# 6    17.57      Texas Tech
# 7    17.25         Arizona
# 8    17.07        Maryland
# 9    16.78         Iowa St
# 10   16.63         Alabama
# 11   16.13       Tennessee
# 12   15.96        Illinois
# 13   14.87          Baylor
# 14   14.76          Kansas
# 15   14.74        Missouri
# 16   14.45        Kentucky
# 17   14.16         Ohio St
# 18   14.02     Michigan St
# 19   13.98       Wisconsin
# 20   13.90             BYU
# 21   13.88       St John's
# 22   13.72          Purdue
# 23   13.57            UCLA
# 24   13.31       Marquette
# 25   13.15     Connecticut
# 26   12.99       Texas A&M
# 27   12.44        Michigan
# 28   12.36           Texas
# 29   12.26  North Carolina
# 30   11.96        Arkansas

# %%
pd.Series([teams[expRs[-i-1][1]] for i in range(31,61)], index = range(31,61))
# Out:
# 31        Louisville
# 32    Mississippi St
# 33        Cincinnati
# 34            Xavier
# 35       Mississippi
# 36           Penn St
# 37      Northwestern
# 38           Clemson
# 39         Villanova
# 40      St Mary's CA
# 41        Pittsburgh
# 42     West Virginia
# 43         Creighton
# 44       Santa Clara
# 45          Oklahoma
# 46        Vanderbilt
# 47               SMU
# 48            Oregon
# 49              Iowa
# 50               VCU
# 51              Utah
# 52           Indiana
# 53               USC
# 54            Butler
# 55        New Mexico
# 56          Boise St
# 57          Nebraska
# 58          Colorado
# 59         Kansas St
# 60       Colorado St
# dtype: object

# %%
# This cell and next one were helpful for finding specific teams
[teams[expRs[-i-1][1]] for i in range(m)].index("Memphis")
# Out:
# 85

# %%
[a for a in teams if a[0] == "C"]
# Out:
# []

# %% [markdown]
# ## PageRank
# Now let's do [PageRank](https://yetanothermathblog.com/2017/01/26/sports-ranking-methods-3/), the non-baby version

# %%
mat = np.zeros((m, m))
game_cnts = np.zeros((m, m))
for i in range(len(df1)):
  game = df1.iloc[i]
  winner, loser = game["Winner"], game["Loser"]
  if winner in teams and loser in teams:
    wInd, lInd = teams.index(game["Winner"]), teams.index(game["Loser"])
    game_cnts[wInd][lInd] += 1
    game_cnts[lInd][wInd] += 1
    mat[wInd][lInd] += game["WinnerScore"]
    mat[lInd][wInd] += game["LoserScore"]

# %%
mat2 = np.zeros((m, m))
for i in range(m):
  for j in range(m):
    mat2[i][j] = max(mat[i][j]-mat[j][i], 0)

# %%
for i in range(m):
  if sum(mat2[i]):
    mat2[i] /= sum(mat2[i] )
  else:
    print("team", i, "didn't win", teams[i])
# Out:
# team 159 didn't win MS Valley St

# %%
J = np.ones((m,m))/m
mat3 = (mat2 + J)/2

# %%
evs = np.dot(np.ones(m)/m, matrix_power(mat2, 100))
exp_vs = [[evs[i],i] for i in range(m)]
exp_vs.sort()
exp_vs[:10]
pgRank = [teams[a[1]] for a in exp_vs if int(sum(game_cnts[a[1]])) > 3]
pd.Series([pgRank[i] for i in range(30)], index = range(1,31))
# Out:
# 1            Drake
# 2          Florida
# 3        St John's
# 4          Houston
# 5           Auburn
# 6        Tennessee
# 7          Alabama
# 8             Duke
# 9         Oklahoma
# 10    St Mary's CA
# 11          Baylor
# 12         Gonzaga
# 13     Michigan St
# 14       Wisconsin
# 15        Michigan
# 16          Kansas
# 17      Texas Tech
# 18         Georgia
# 19          Purdue
# 20       Texas A&M
# 21        Missouri
# 22         Arizona
# 23          Oregon
# 24      McNeese St
# 25    San Diego St
# 26        Nebraska
# 27        Kentucky
# 28     Mississippi
# 29         Ohio St
# 30            Iowa
# dtype: object

# %%
pd.Series([pgRank[i] for i in range(30,60)], index = range(31,61))
# Out:
# 31           Penn St
# 32        Vanderbilt
# 33          Maryland
# 34               UCF
# 35              Utah
# 36           Iowa St
# 37          Illinois
# 38              UCLA
# 39           Utah St
# 40           Liberty
# 41        Arizona St
# 42    North Carolina
# 43           Indiana
# 44     San Francisco
# 45               BYU
# 46               TCU
# 47         Creighton
# 48               USC
# 49       Wake Forest
# 50              UNLV
# 51          Colorado
# 52           Clemson
# 53               LSU
# 54       S Dakota St
# 55      Northwestern
# 56         Minnesota
# 57       Colorado St
# 58         Marquette
# 59     West Virginia
# 60       Connecticut
# dtype: object

# %%
pgRank.index("Colorado St")
# Out:
# 56

# %%
[a for a in teams if a[0] == "C"]
# Out:
# ['C Michigan',
#  'CS Bakersfield',
#  'CS Fullerton',
#  'CS Northridge',
#  'CS Sacramento',
#  'Cal Baptist',
#  'Cal Poly',
#  'California',
#  'Campbell',
#  'Canisius',
#  'Cent Arkansas',
#  'Central Conn',
#  'Charleston So',
#  'Charlotte',
#  'Chattanooga',
#  'Chicago St',
#  'Cincinnati',
#  'Citadel',
#  'Clemson',
#  'Cleveland St',
#  'Coastal Car',
#  'Col Charleston',
#  'Colgate',
#  'Colorado',
#  'Colorado St',
#  'Columbia',
#  'Connecticut',
#  'Coppin St',
#  'Cornell',
#  'Creighton']

# %%
# take a peek at the values within the eigenvector. The top 7 teams were net positive against each of their opponents
pd.DataFrame({"Team" : [pgRank[i] for i in range(30)], "Points" : exp_vs[:30]}, index = range(1,31))
# Out:
#             Team                         Points
# 1          Drake                      [0.0, 28]
# 2        Florida                      [0.0, 74]
# 3      St John's                      [0.0, 91]
# 4        Houston                     [0.0, 177]
# 5         Auburn                     [0.0, 188]
# 6      Tennessee                     [0.0, 252]
# 7        Alabama                     [0.0, 367]
# 8           Duke  [3.9785107837423325e-09, 285]
# 9       Oklahoma   [8.229809868671208e-09, 115]
# 10  St Mary's CA   [1.7906001816134335e-08, 16]
# 11        Baylor   [3.346912683608454e-08, 302]
# 12       Gonzaga     [5.178293836229945e-08, 3]
# 13   Michigan St    [6.185056310416621e-08, 76]
# 14     Wisconsin   [9.327645037348971e-08, 225]
# 15      Michigan   [1.059670167137296e-07, 288]
# 16        Kansas    [2.007408077509155e-07, 20]
# 17    Texas Tech  [2.4841613749732096e-07, 106]
# 18       Georgia    [2.50029842002799e-07, 176]
# 19        Purdue   [2.634594839206898e-07, 362]
# 20     Texas A&M   [2.995121210689065e-07, 175]
# 21      Missouri  [2.9957118857003284e-07, 134]
# 22       Arizona   [3.041219504705078e-07, 308]
# 23        Oregon  [3.6939818245681284e-07, 103]
# 24    McNeese St    [4.04359851733762e-07, 243]
# 25  San Diego St   [4.334550402141989e-07, 306]
# 26      Nebraska   [4.508017310129383e-07, 181]
# 27      Kentucky     [4.719086331489075e-07, 9]
# 28   Mississippi   [4.953783815139517e-07, 229]
# 29       Ohio St   [5.197686656189728e-07, 168]
# 30          Iowa   [5.347901502356499e-07, 268]
